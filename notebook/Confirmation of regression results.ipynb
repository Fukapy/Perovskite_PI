# %% [markdown]
# # Confirmation of regression results

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix, save_npz, load_npz

# %%
def yypair(X_name,model,split_way,Per_elem_prop,fill_way,rs):
    train = pd.read_csv(f"data/model/regression/{X_name}_Train_{model}_sp{str(split_way)}_{Per_elem_prop}_{fill_way}_r{str(rs)}.csv")
    test = pd.read_csv(f"data/model/regression/{X_name}_Predict_{model}_sp{str(split_way)}_{Per_elem_prop}_{fill_way}_r{str(rs)}.csv")
    y_train_real = train["y_train_real"]
    y_train_pred = train["y_train_pred"]
    y_test_real = test["y_test_real"]
    y_test_pred = test["y_test_pred"]
    return y_train_real, y_train_pred, y_test_real, y_test_pred

# %%
def metrics(y_train_real,y_train_pred,y_test_real,y_test_pred):
    R2_train = r2_score(y_train_real,y_train_pred)
    RMSE_train = np.sqrt(mean_squared_error(y_train_real,y_train_pred))
    MAE_train = mean_absolute_error(y_train_real,y_train_pred)
    R2_test = r2_score(y_test_real,y_test_pred)
    RMSE_test = np.sqrt(mean_squared_error(y_test_real,y_test_pred))
    MAE_test = mean_absolute_error(y_test_real,y_test_pred)
    print("R2_train",R2_train)
    print("RMSE_train",RMSE_train)
    print("MAE_train",MAE_train)
    print("R2_test",R2_test)
    print("RMSE_test",RMSE_test)
    print("MAE_test",MAE_test)
    return R2_train,RMSE_train,MAE_train,R2_test,RMSE_test,MAE_test

# %%
def vec2csr(vec, csr_file_name, columns_file_name):
    csr = csr_matrix(vec)
    save_npz(csr_file_name, csr)
    if columns_file_name != None:
        columns_arr = np.array(vec.columns)
        np.save(columns_file_name, columns_arr)
def csr2vec(csr_file_name, columns_file_name):
    if columns_file_name == None:
        vec = load_npz(csr_file_name).toarray()
    else:
        vec = pd.DataFrame(load_npz(csr_file_name).toarray(),
             columns=np.load(columns_file_name,allow_pickle=True))
    return vec

# %%
X_name = "per"
model = "RF"
split_way = 0
fill_way = "dummy"
rs = 0
for Per_elem_prop in ["dummy", "oliynyk", "magpie", "mat2vec"]:
    print(Per_elem_prop)
    y_train_real,y_train_pred,y_test_real,y_test_pred = yypair(X_name,model,split_way,Per_elem_prop,fill_way,rs)
    metrics(y_train_real,y_train_pred,y_test_real,y_test_pred)
# Out:
# dummy
# R2_train 0.31045483274787533
# RMSE_train 4.280671004557138
# MAE_train 3.3410177083903974
# R2_test 0.2261743309365961
# RMSE_test 4.488814996102282
# MAE_test 3.504169206880919
# oliynyk
# R2_train 0.3159383067204564
# RMSE_train 4.263616428838994
# MAE_train 3.312093691338334
# R2_test 0.2928636310593785
# RMSE_test 4.291031747554234
# MAE_test 3.3897158724750844
# magpie
# R2_train 0.31557789113347434
# RMSE_train 4.264739479199206
# MAE_train 3.3143944801025444
# R2_test 0.29011068380696137
# RMSE_test 4.299376325519478
# MAE_test 3.3955069924625776
# mat2vec
# R2_train 0.3160185065616026
# RMSE_train 4.263366486921032
# MAE_train 3.3109356498078033
# R2_test 0.29215277076516344
# RMSE_test 4.293188020384088
# MAE_test 3.3925396256087885

# %%
# confirmation of dimension
for fill in ["dummy", "zero", "median"]:
    for split in [0, 1, 2, 3]:
        print(fill, split)
        csr_file_name = f"data/csr/all_sp{split}_oliynyk_{fill}_csr.npz"
        columns_file_name = f"data/csr/all_sp{split}_oliynyk_{fill}_columns.npy"
        print(np.shape(csr2vec(csr_file_name, columns_file_name)))
# Out:
# dummy 0
# (36937, 18716)
# dummy 1
# (36937, 17297)
# dummy 2
# (36937, 13460)
# dummy 3
# (36937, 12834)
# zero 0
# (36937, 15854)
# zero 1
# (36937, 15305)
# zero 2
# (36937, 11926)
# zero 3
# (36937, 11300)
# median 0
# (36937, 15854)
# median 1
# (36937, 15305)
# median 2
# (36937, 11926)
# median 3
# (36937, 11300)

# %%
X_name = "all"
model = "RF"
Per_elem_prop = "oliynyk"
rs = 0
for fill_way in ["dummy", "zero", "median"]:
    for split_way in [0, 1, 2, 3]:
        print(fill_way, split_way)
        y_train_real,y_train_pred,y_test_real,y_test_pred = yypair(X_name,model,split_way,Per_elem_prop,fill_way,rs)
        metrics(y_train_real,y_train_pred,y_test_real,y_test_pred)
# Out:
# dummy 0
# R2_train 0.8612364258953665
# RMSE_train 1.9202962336790597
# MAE_train 1.3208436094279798
# R2_test 0.7018628765077705
# RMSE_test 2.7862377310418456
# MAE_test 1.9813863497274569
# dummy 1
# R2_train 0.8624454623013118
# RMSE_train 1.9119122343471617
# MAE_train 1.3145547933768353
# R2_test 0.7020392440024807
# RMSE_test 2.785413488730015
# MAE_test 1.9834825162579364
# dummy 2
# R2_train 0.8912890217516675
# RMSE_train 1.6996801143654838
# MAE_train 1.1572640301890824
# R2_test 0.7034531804589257
# RMSE_test 2.778796709482962
# MAE_test 1.9568296884224294
# dummy 3
# R2_train 0.899692663498277
# RMSE_train 1.6326640902794523
# MAE_train 1.0884609295746537
# R2_test 0.7059331642756556
# RMSE_test 2.7671529505647956
# MAE_test 1.9438273490037061
# zero 0
# R2_train 0.8573917396046113
# RMSE_train 1.9467170497721238
# MAE_train 1.344250824741859
# R2_test 0.7061417106395838
# RMSE_test 2.766171571562107
# MAE_test 1.9778658274670298
# zero 1
# R2_train 0.908266703920174
# RMSE_train 1.5613274338071035
# MAE_train 1.021435561009002
# R2_test 0.7176564978139601
# RMSE_test 2.7114340109390627
# MAE_test 1.894081456098569
# zero 2
# R2_train 0.8588994928500847
# RMSE_train 1.9363986839689133
# MAE_train 1.3847999368753776
# R2_test 0.6983563492638722
# RMSE_test 2.8025749430748577
# MAE_test 2.00237443879842
# zero 3
# R2_train 0.8997699847434413
# RMSE_train 1.6320347048230968
# MAE_train 1.0883469749151524
# R2_test 0.7126475272409696
# RMSE_test 2.73537963965431
# MAE_test 1.9195954451621422
# median 0
# R2_train 0.9078845812092585
# RMSE_train 1.5645759742585086
# MAE_train 1.0242538568596131
# R2_test 0.7153312007243556
# RMSE_test 2.722576398577267
# MAE_test 1.9029970921748507
# median 1
# R2_train 0.8975935848856995
# RMSE_train 1.6496585911064205
# MAE_train 1.1069048122344405
# R2_test 0.7124577094677207
# RMSE_test 2.7362829517939433
# MAE_test 1.9204947641415757
# median 2
# R2_train 0.8961117006657378
# RMSE_train 1.6615515116630948
# MAE_train 1.1198327888318766
# R2_test 0.7098557840850839
# RMSE_test 2.748635170431535
# MAE_test 1.9331941804266177
# median 3
# R2_train 0.8735752567366785
# RMSE_train 1.83293275240979
# MAE_train 1.279262875466674
# R2_test 0.7059812410382076
# RMSE_test 2.7669267414566776
# MAE_test 1.9646796690075776

# %%
X_name = "all"
Per_elem_prop = "oliynyk"
fill_way = "zero"
split_way = 1
rs = 0
for model in ["RF", "GBDT", "NN"]:
    print(model)
    y_train_real,y_train_pred,y_test_real,y_test_pred = yypair(X_name,model,split_way,Per_elem_prop,fill_way,rs)
    metrics(y_train_real,y_train_pred,y_test_real,y_test_pred)
# Out:
# RF
# R2_train 0.908266703920174
# RMSE_train 1.5613274338071035
# MAE_train 1.021435561009002
# R2_test 0.7176564978139601
# RMSE_test 2.7114340109390627
# MAE_test 1.894081456098569
# GBDT
# R2_train 0.6182012123011054
# RMSE_train 3.1852810947250565
# MAE_train 2.39353105925077
# R2_test 0.5589016919355678
# RMSE_test 3.389048910645667
# MAE_test 2.5645125205669435
# NN
# R2_train 0.6295917391406054
# RMSE_train 3.1374067265603673
# MAE_train 2.2548940110472353
# R2_test 0.5657699112085222
# RMSE_test 3.3625604251308645
# MAE_test 2.462016643822462

# %%
X_name = "all"
model = "RF"
Per_elem_prop = "oliynyk"
for rs in [0,1,2,3,4]:
    for fill_way in ["dummy", "zero", "median"]:
        for split_way in [0, 1, 2, 3]:
            print("rs:",rs, "fill_way:",fill_way, "split_way:",split_way)
            y_train_real,y_train_pred,y_test_real,y_test_pred = yypair(X_name,model,split_way,Per_elem_prop,fill_way,rs)
            metrics(y_train_real,y_train_pred,y_test_real,y_test_pred)
# Out:
# rs: 0 fill_way: dummy split_way: 0
# R2_train 0.8612364258953665
# RMSE_train 1.9202962336790597
# MAE_train 1.3208436094279798
# R2_test 0.7018628765077705
# RMSE_test 2.7862377310418456
# MAE_test 1.9813863497274569
# rs: 0 fill_way: dummy split_way: 1
# R2_train 0.8624454623013118
# RMSE_train 1.9119122343471617
# MAE_train 1.3145547933768353
# R2_test 0.7020392440024807
# RMSE_test 2.785413488730015
# MAE_test 1.9834825162579364
# rs: 0 fill_way: dummy split_way: 2
# R2_train 0.8912890217516675
# RMSE_train 1.6996801143654838
# MAE_train 1.1572640301890824
# R2_test 0.7034531804589257
# RMSE_test 2.778796709482962
# MAE_test 1.9568296884224294
# rs: 0 fill_way: dummy split_way: 3
# R2_train 0.899692663498277
# RMSE_train 1.6326640902794523
# MAE_train 1.0884609295746537
# R2_test 0.7059331642756556
# RMSE_test 2.7671529505647956
# MAE_test 1.9438273490037061
# rs: 0 fill_way: zero split_way: 0
# R2_train 0.8573917396046113
# RMSE_train 1.9467170497721238
# MAE_train 1.344250824741859
# R2_test 0.7061417106395838
# RMSE_test 2.766171571562107
# MAE_test 1.9778658274670298
# rs: 0 fill_way: zero split_way: 1
# R2_train 0.908266703920174
# RMSE_train 1.5613274338071035
# MAE_train 1.021435561009002
# R2_test 0.7176564978139601
# RMSE_test 2.7114340109390627
# MAE_test 1.894081456098569
# rs: 0 fill_way: zero split_way: 2
# R2_train 0.8588994928500847
# RMSE_train 1.9363986839689133
# MAE_train 1.3847999368753776
# R2_test 0.6983563492638722
# RMSE_test 2.8025749430748577
# MAE_test 2.00237443879842
# rs: 0 fill_way: zero split_way: 3
# R2_train 0.8997699847434413
# RMSE_train 1.6320347048230968
# MAE_train 1.0883469749151524
# R2_test 0.7126475272409696
# RMSE_test 2.73537963965431
# MAE_test 1.9195954451621422
# rs: 0 fill_way: median split_way: 0
# R2_train 0.9078845812092585
# RMSE_train 1.5645759742585086
# MAE_train 1.0242538568596131
# R2_test 0.7153312007243556
# RMSE_test 2.722576398577267
# MAE_test 1.9029970921748507
# rs: 0 fill_way: median split_way: 1
# R2_train 0.8975935848856995
# RMSE_train 1.6496585911064205
# MAE_train 1.1069048122344405
# R2_test 0.7124577094677207
# RMSE_test 2.7362829517939433
# MAE_test 1.9204947641415757
# rs: 0 fill_way: median split_way: 2
# R2_train 0.8961117006657378
# RMSE_train 1.6615515116630948
# MAE_train 1.1198327888318766
# R2_test 0.7098557840850839
# RMSE_test 2.748635170431535
# MAE_test 1.9331941804266177
# rs: 0 fill_way: median split_way: 3
# R2_train 0.8735752567366785
# RMSE_train 1.83293275240979
# MAE_train 1.279262875466674
# R2_test 0.7059812410382076
# RMSE_test 2.7669267414566776
# MAE_test 1.9646796690075776
# rs: 1 fill_way: dummy split_way: 0
# R2_train 0.8608232117468725
# RMSE_train 1.920388059410368
# MAE_train 1.3207068363758512
# R2_test 0.6961132200952871
# RMSE_test 2.8294406985153957
# MAE_test 2.0006460762392564
# rs: 1 fill_way: dummy split_way: 1
# R2_train 0.8624355292121
# RMSE_train 1.9092321227723346
# MAE_train 1.312369988744999
# R2_test 0.6983701820994551
# RMSE_test 2.818914012465243
# MAE_test 1.994057383458291
# rs: 1 fill_way: dummy split_way: 2
# R2_train 0.891219397540947
# RMSE_train 1.6977796422335247
# MAE_train 1.1562996379217145
# R2_test 0.6989387856253182
# RMSE_test 2.816255786311354
# MAE_test 1.9602808345321794
# rs: 1 fill_way: dummy split_way: 3
# R2_train 0.8994512622141595
# RMSE_train 1.6322771590032088
# MAE_train 1.087790919690051
# R2_test 0.7009578614145296
# RMSE_test 2.806796248799794
# MAE_test 1.9437168645169647
# rs: 1 fill_way: zero split_way: 0
# R2_train 0.857904931592433
# RMSE_train 1.9404171061426019
# MAE_train 1.3409649399489272
# R2_test 0.6965804544428651
# RMSE_test 2.827264690023512
# MAE_test 1.9951000921406228
# rs: 1 fill_way: zero split_way: 1
# R2_train 0.9079412002832722
# RMSE_train 1.5618461304773072
# MAE_train 1.0234232394807896
# R2_test 0.7109991748090816
# RMSE_test 2.7592702209158833
# MAE_test 1.8954040259221188
# rs: 1 fill_way: zero split_way: 2
# R2_train 0.8593466658500014
# RMSE_train 1.9305480153694508
# MAE_train 1.379352632422949
# R2_test 0.6890936991434287
# RMSE_test 2.8619329466505685
# MAE_test 2.0287710280979816
# rs: 1 fill_way: zero split_way: 3
# R2_train 0.8993164220855651
# RMSE_train 1.6333712688181445
# MAE_train 1.0895856402262925
# R2_test 0.705454457240295
# RMSE_test 2.785613894726389
# MAE_test 1.9267260014670526
# rs: 1 fill_way: median split_way: 0
# R2_train 0.9076183077981544
# RMSE_train 1.56458278869763
# MAE_train 1.02503942846023
# R2_test 0.7057591312459295
# RMSE_test 2.7841728209264494
# MAE_test 1.908489687876737
# rs: 1 fill_way: median split_way: 1
# R2_train 0.8976531211902805
# RMSE_train 1.6468077164267438
# MAE_train 1.1071358177352484
# R2_test 0.706388401293981
# RMSE_test 2.781194080600728
# MAE_test 1.9201727390062373
# rs: 1 fill_way: median split_way: 2
# R2_train 0.8960239509905914
# RMSE_train 1.6598630114483999
# MAE_train 1.1197306468914838
# R2_test 0.7038396011615036
# RMSE_test 2.793239569048084
# MAE_test 1.9301143486681536
# rs: 1 fill_way: median split_way: 3
# R2_train 0.8734300816708513
# RMSE_train 1.8313478452226153
# MAE_train 1.2797101291361903
# R2_test 0.6977111723929573
# RMSE_test 2.821991755459931
# MAE_test 1.982443243130323
# rs: 2 fill_way: dummy split_way: 0
# R2_train 0.863528638960171
# RMSE_train 1.8989693639407716
# MAE_train 1.3063186413411512
# R2_test 0.6865443524725319
# RMSE_test 2.8897835402561802
# MAE_test 2.03217125193731
# rs: 2 fill_way: dummy split_way: 1
# R2_train 0.8644058682125526
# RMSE_train 1.8928562971922671
# MAE_train 1.300576737442123
# R2_test 0.6892813206899615
# RMSE_test 2.8771396676020564
# MAE_test 2.021590333836308
# rs: 2 fill_way: dummy split_way: 2
# R2_train 0.8926448709197952
# RMSE_train 1.6842579118363687
# MAE_train 1.1479302003737184
# R2_test 0.6883508510925503
# RMSE_test 2.881444348935753
# MAE_test 1.9927756102975343
# rs: 2 fill_way: dummy split_way: 3
# R2_train 0.9004996238575554
# RMSE_train 1.6214723905555526
# MAE_train 1.0806591421996459
# R2_test 0.6921097748967345
# RMSE_test 2.86401451175206
# MAE_test 1.9748370380713538
# rs: 2 fill_way: zero split_way: 0
# R2_train 0.8599770241581495
# RMSE_train 1.9235206300662173
# MAE_train 1.328681263759305
# R2_test 0.6841002281152897
# RMSE_test 2.9010279948601507
# MAE_test 2.0404194091779333
# rs: 2 fill_way: zero split_way: 1
# R2_train 0.9093686972587618
# RMSE_train 1.5475201343808684
# MAE_train 1.013692118732423
# R2_test 0.697415604057877
# RMSE_test 2.8392296887378285
# MAE_test 1.9452303055998674
# rs: 2 fill_way: zero split_way: 2
# R2_train 0.8616484020859598
# RMSE_train 1.9120061578515688
# MAE_train 1.3669433524039574
# R2_test 0.6801432024469716
# RMSE_test 2.919140887295087
# MAE_test 2.0602993271214904
# rs: 2 fill_way: zero split_way: 3
# R2_train 0.9008159245758004
# RMSE_train 1.6188930981832121
# MAE_train 1.0808293646839473
# R2_test 0.6941174392828753
# RMSE_test 2.854661528694922
# MAE_test 1.9683318428278496
# rs: 2 fill_way: median split_way: 0
# R2_train 0.9090798804457327
# RMSE_train 1.5499839317100412
# MAE_train 1.0143026095101841
# R2_test 0.6973767118190107
# RMSE_test 2.8394121509742543
# MAE_test 1.942158211690621
# rs: 2 fill_way: median split_way: 1
# R2_train 0.8986749069427103
# RMSE_train 1.6362727677499433
# MAE_train 1.0973146573447055
# R2_test 0.6955325482280544
# RMSE_test 2.84805059266256
# MAE_test 1.9626924551209306
# rs: 2 fill_way: median split_way: 2
# R2_train 0.8975918471101536
# RMSE_train 1.64499454981242
# MAE_train 1.108389585367399
# R2_test 0.6919021458300991
# RMSE_test 2.864980038411601
# MAE_test 1.9779807692091247
# rs: 2 fill_way: median split_way: 3
# R2_train 0.8754858223098825
# RMSE_train 1.8138718432679561
# MAE_train 1.26694578487554
# R2_test 0.6857435729990808
# RMSE_test 2.8934724246496377
# MAE_test 2.0218936196264115
# rs: 3 fill_way: dummy split_way: 0
# R2_train 0.8609431943189932
# RMSE_train 1.9180956334506731
# MAE_train 1.3173925853536943
# R2_test 0.6995263770349571
# RMSE_test 2.8221132390444
# MAE_test 1.9873480283343226
# rs: 3 fill_way: dummy split_way: 1
# R2_train 0.8619249791019566
# RMSE_train 1.9113124601917026
# MAE_train 1.312168105168863
# R2_test 0.7011805162198756
# RMSE_test 2.8143345021249404
# MAE_test 1.9812863666450742
# rs: 3 fill_way: dummy split_way: 2
# R2_train 0.8915780590699283
# RMSE_train 1.693685311178748
# MAE_train 1.1527738548157138
# R2_test 0.7009033962410476
# RMSE_test 2.81563918208294
# MAE_test 1.950166228852396
# rs: 3 fill_way: dummy split_way: 3
# R2_train 0.8994512947793876
# RMSE_train 1.631031593402723
# MAE_train 1.0871549674409196
# R2_test 0.7020597787304503
# RMSE_test 2.8101909272555377
# MAE_test 1.9401320843017376
# rs: 3 fill_way: zero split_way: 0
# R2_train 0.8575365419749054
# RMSE_train 1.9414484930900633
# MAE_train 1.3404399273334138
# R2_test 0.7016985429274116
# RMSE_test 2.811894010608662
# MAE_test 1.9787091828919088
# rs: 3 fill_way: zero split_way: 1
# R2_train 0.9081634070339131
# RMSE_train 1.5587699110114581
# MAE_train 1.019176076197605
# R2_test 0.7094522329459197
# RMSE_test 2.775108900907804
# MAE_test 1.9022582153195142
# rs: 3 fill_way: zero split_way: 2
# R2_train 0.8593997265857364
# RMSE_train 1.9287112551675163
# MAE_train 1.3758139017262028
# R2_test 0.698153906941656
# RMSE_test 2.82855116375506
# MAE_test 2.0032306980400496
# rs: 3 fill_way: zero split_way: 3
# R2_train 0.8996958362836304
# RMSE_train 1.6290469943739303
# MAE_train 1.0858011031589845
# R2_test 0.707302365353546
# RMSE_test 2.7853569937313356
# MAE_test 1.9247520031501084
# rs: 3 fill_way: median split_way: 0
# R2_train 0.9078571045694724
# RMSE_train 1.5613672286958138
# MAE_train 1.0223195546234571
# R2_test 0.7063844521492306
# RMSE_test 2.7897210785465143
# MAE_test 1.9131428483066248
# rs: 3 fill_way: median split_way: 1
# R2_train 0.897472142993451
# RMSE_train 1.647005586483479
# MAE_train 1.104486301410115
# R2_test 0.7066141245886545
# RMSE_test 2.7886297749765805
# MAE_test 1.9247995203701371
# rs: 3 fill_way: median split_way: 2
# R2_train 0.895754113711855
# RMSE_train 1.6607474537311084
# MAE_train 1.1174026395048204
# R2_test 0.7054674218389654
# RMSE_test 2.79407415931395
# MAE_test 1.9317596874677985
# rs: 3 fill_way: median split_way: 3
# R2_train 0.8743208172827979
# RMSE_train 1.8235001617329836
# MAE_train 1.2744182678525906
# R2_test 0.6991906367239642
# RMSE_test 2.823689471657843
# MAE_test 1.9765905471634495
# rs: 4 fill_way: dummy split_way: 0
# R2_train 0.8587134480242042
# RMSE_train 1.9333540183442468
# MAE_train 1.330193139419998
# R2_test 0.7116309452741562
# RMSE_test 2.7650582229427325
# MAE_test 1.9542138574533414
# rs: 4 fill_way: dummy split_way: 1
# R2_train 0.8598446845167036
# RMSE_train 1.9255985879205355
# MAE_train 1.322109563550549
# R2_test 0.713069005711445
# RMSE_test 2.75815510604227
# MAE_test 1.9493455780754279
# rs: 4 fill_way: dummy split_way: 2
# R2_train 0.8893210472976252
# RMSE_train 1.7111713198869822
# MAE_train 1.1643834847920624
# R2_test 0.7156671432254469
# RMSE_test 2.7456392707064516
# MAE_test 1.917770961931185
# rs: 4 fill_way: dummy split_way: 3
# R2_train 0.897676770381443
# RMSE_train 1.6453113428983817
# MAE_train 1.0949905473957755
# R2_test 0.718810710480259
# RMSE_test 2.730419273208455
# MAE_test 1.8949883073979186
# rs: 4 fill_way: zero split_way: 0
# R2_train 0.8554139000950917
# RMSE_train 1.9557991079090438
# MAE_train 1.3500821154956661
# R2_test 0.7140017350740782
# RMSE_test 2.7536684761307195
# MAE_test 1.9578618053918702
# rs: 4 fill_way: zero split_way: 1
# R2_train 0.9063624446571883
# RMSE_train 1.5739321460528504
# MAE_train 1.0277941339748156
# R2_test 0.7227703471820237
# RMSE_test 2.7111265756763685
# MAE_test 1.8750621669014067
# rs: 4 fill_way: zero split_way: 2
# R2_train 0.8564749920032112
# RMSE_train 1.9486092598605917
# MAE_train 1.388283644843657
# R2_test 0.7077329418907305
# RMSE_test 2.7836837080328753
# MAE_test 1.983804836618187
# rs: 4 fill_way: zero split_way: 3
# R2_train 0.8974255396105414
# RMSE_train 1.647329943302096
# MAE_train 1.0965008560037552
# R2_test 0.7225451971273151
# RMSE_test 2.7122272631494755
# MAE_test 1.8917407340398218
# rs: 4 fill_way: median split_way: 0
# R2_train 0.9063018503021381
# RMSE_train 1.5744413219857076
# MAE_train 1.0290146596110663
# R2_test 0.7180891642677754
# RMSE_test 2.7339202270457665
# MAE_test 1.8862814116967426
# rs: 4 fill_way: median split_way: 1
# R2_train 0.8955670735241952
# RMSE_train 1.6621862914703147
# MAE_train 1.113944007619945
# R2_test 0.715782813338041
# RMSE_test 2.7450807339381726
# MAE_test 1.9037019373095563
# rs: 4 fill_way: median split_way: 2
# R2_train 0.8939962761622904
# RMSE_train 1.674640280311687
# MAE_train 1.126587208271594
# R2_test 0.7191911274886862
# RMSE_test 2.7285716753123648
# MAE_test 1.899182376944483
# rs: 4 fill_way: median split_way: 3
# R2_train 0.8716985171138883
# RMSE_train 1.842369816950681
# MAE_train 1.2851183657952114
# R2_test 0.7143265022117276
# RMSE_test 2.7521045592030986
# MAE_test 1.9419180174747979
